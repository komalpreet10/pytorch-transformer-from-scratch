# %% [markdown]
# # 04 — LoRA
# Low-rank adaptation on attention layers. GPU needed.

# %%
import os, sys
from pathlib import Path

IS_KAGGLE = Path("/kaggle/working").exists()

if IS_KAGGLE:
    REPO_URL = "https://github.com/komalpreet10/medical-llm-peft-benchmark"
    REPO_DIR = Path("/kaggle/working/medical-llm-peft-benchmark")

    if not REPO_DIR.exists():
        # !git clone {REPO_URL} {REPO_DIR}

    os.chdir(REPO_DIR)
    sys.path.insert(0, str(REPO_DIR))

    from src.setup import setup_kaggle
    setup_kaggle()
else:
    sys.path.insert(0, "..")

    from src.setup import setup_local
    setup_local()

# %%
from src.data_utils  import get_tokenizer, load_train_data, load_test_data
from src.model_utils import load_base_model, get_lora_config, apply_lora, count_parameters
from src.train_utils import init_trackers, get_training_args, get_trainer, log_metrics, end_trackers
from src.eval_utils  import evaluate_model, save_metrics

init_trackers("lora")

# %%
tokenizer  = get_tokenizer()
train_data = load_train_data(tokenizer)
test_data  = load_test_data()

# %%
model  = load_base_model()
config = get_lora_config("configs/lora_config.yaml")
model  = apply_lora(model, config)
params = count_parameters(model)
print(params)

# %%
args    = get_training_args("./outputs/lora")
trainer = get_trainer(model, tokenizer, train_data, args)
trainer.train()
trainer.save_model("./outputs/lora/final")

# %%
metrics = evaluate_model(model, tokenizer, test_data, "lora")
metrics.update(params)
save_metrics(metrics, "results/lora_metrics.json")

# %%
log_metrics(metrics)
end_trackers()
print("LoRA complete")
